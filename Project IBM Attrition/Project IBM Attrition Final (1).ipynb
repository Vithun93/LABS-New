# %% [markdown]
# # Problem Definition

# %% [markdown]
# IBM HR Data Base for Employee Attrition Analysis

# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd 
import pandas as np 
import matplotlib.pyplot as plt
import math
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
#uploading the data 
ibm= pd.read_csv(r"C:\Users\Vithushan\Downloads\IBM.csv")

# %% [markdown]
# # Displaying the Dataset

# %%
ibm
# Out:
#       Age Attrition              Department  DistanceFromHome  Education  \
# 0      41       Yes                   Sales                 1          2
# 1      49        No  Research & Development                 8          1
# 2      37       Yes  Research & Development                 2          2
# 3      33        No  Research & Development                 3          4
# 4      27        No  Research & Development                 2          1
# ...   ...       ...                     ...               ...        ...
# 1465   36        No  Research & Development                23          2
# 1466   39        No  Research & Development                 6          1
# 1467   27        No  Research & Development                 4          3
# 1468   49        No                   Sales                 2          3
# 1469   34        No  Research & Development                 8          3
#
#      EducationField  EnvironmentSatisfaction  JobSatisfaction MaritalStatus  \
# ...

# %%
# Show the number of columns and rows 
ibm.shape
# Out:
# (1470, 13)

# %%
ibm.dtypes
# Out:
# Age                         int64
# Attrition                  object
# Department                 object
# DistanceFromHome            int64
# Education                   int64
# EducationField             object
# EnvironmentSatisfaction     int64
# JobSatisfaction             int64
# MaritalStatus              object
# MonthlyIncome               int64
# NumCompaniesWorked          int64
# WorkLifeBalance             int64
# YearsAtCompany              int64
# dtype: object

# %% [markdown]
# # Data Processing

# %%
ibm["Department"].value_counts()
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64

# %%
ibm ["EducationField"].value_counts()
# Out:
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64

# %%
cat=[]
cont=[]
for i in ibm.columns:
    if ibm[i].dtypes == "object":
        cat.append(i)
    else:
        cont.append(i)
print("caterorical data columns are :", cat)
print("continuous data columns are :", cont)
# Out:
# caterorical data columns are : ['Attrition', 'Department', 'EducationField', 'MaritalStatus']
# continuous data columns are : ['Age', 'DistanceFromHome', 'Education', 'EnvironmentSatisfaction', 'JobSatisfaction', 'MonthlyIncome', 'NumCompaniesWorked', 'WorkLifeBalance', 'YearsAtCompany']

# %%
ibm.isnull().sum()
# Out:
# Age                        0
# Attrition                  0
# Department                 0
# DistanceFromHome           0
# Education                  0
# EducationField             0
# EnvironmentSatisfaction    0
# JobSatisfaction            0
# MaritalStatus              0
# MonthlyIncome              0
# NumCompaniesWorked         0
# WorkLifeBalance            0
# YearsAtCompany             0
# dtype: int64

# %%
ibm.describe()
# Out:
#                Age  DistanceFromHome    Education  EnvironmentSatisfaction  \
# count  1470.000000       1470.000000  1470.000000              1470.000000
# mean     36.923810          9.192517     2.912925                 2.721769
# std       9.135373          8.106864     1.024165                 1.093082
# min      18.000000          1.000000     1.000000                 1.000000
# 25%      30.000000          2.000000     2.000000                 2.000000
# 50%      36.000000          7.000000     3.000000                 3.000000
# 75%      43.000000         14.000000     4.000000                 4.000000
# max      60.000000         29.000000     5.000000                 4.000000
#
#        JobSatisfaction  MonthlyIncome  NumCompaniesWorked  WorkLifeBalance  \
# count      1470.000000    1470.000000         1470.000000      1470.000000
# mean          2.728571    6502.931293            2.693197         2.761224
# ...

# %% [markdown]
# # Profile of the Employees

# %% [markdown]
# # 1- Education

# %%
pd.crosstab(ibm["Department"],ibm["EducationField"])
# Out:
# EducationField          Human Resources  Life Sciences  Marketing  Medical  \
# Department
# Human Resources                      27             16          0       13
# Research & Development                0            440          0      363
# Sales                                 0            150        159       88
#
# EducationField          Other  Technical Degree
# Department
# Human Resources             3                 4
# Research & Development     64                94
# Sales                      15                34

# %%
pd.crosstab(ibm["Department"],ibm["EducationField"]).plot(figsize=(14,8));

# %% [markdown]
# # Age

# %%
# a histograme about age groups 
plt.hist(ibm['Age'],bins=20)
plt.xlabel('Age')
plt.ylabel('Frequencies') 
plt.title('Frequency distribution Age')
plt.grid()
plt.show()

# %%
# histogram using 20 bins +  kde 
sns.histplot(ibm['Age'], bins=20, kde=True);

# %%
#More details with kde

# %%
sns.kdeplot(ibm["Age"], bw_adjust= 0.3, fill=True);

# %%
x=ibm["MaritalStatus"].value_counts()
x
x=list(x)
x
labels=["Married","Single","Divorced"]
explode = (0.1, 0.1, 0.1)
fig = plt.figure(figsize = (8, 8))
plt.pie(x,labels=labels, explode=explode,autopct='%1.2f%%')
plt.show()

# %%
#We use countplot to understand what's the distance employees make to get to work
sns.countplot(x="DistanceFromHome", data=ibm)
# Out:
# <AxesSubplot:xlabel='DistanceFromHome', ylabel='count'>

# %%
y=ibm["Attrition"].value_counts()
y
y=list(y)
y
labels=["No","Yes"]
explode = [0, 0.2]
fig = plt.figure(figsize = (8, 8))
plt.pie(y,labels=labels, autopct='%.0f%%',explode = explode)
plt.title('Attrition of workers in IBM')
plt.show()

# %% [markdown]
# #### We can see that the data is unbalanced.

# %%
sns.lineplot(x=ibm["NumCompaniesWorked"],y = ibm["JobSatisfaction"],data = ibm);

# %%
# Here we observe that we have a q1 is around 2500 and 
plt.boxplot(ibm['MonthlyIncome'])
plt.title("Monthly Income")
# Out:
# Text(0.5, 1.0, 'Monthly Income')

# %%
sns.set_theme(style="whitegrid")

ax = sns.boxplot(x=ibm["MonthlyIncome"], color="g")

# %%
# the plot is the same as above, but this one is disagregated by field 
ax = sns.boxplot(x="EducationField", y="MonthlyIncome", data=ibm)
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
# Out:
# [Text(0, 0, 'Life Sciences'),
#  Text(1, 0, 'Other'),
#  Text(2, 0, 'Medical'),
#  Text(3, 0, 'Marketing'),
#  Text(4, 0, 'Technical Degree'),
#  Text(5, 0, 'Human Resources')]

# %%
plt.figure(figsize=(14,8), dpi=200)

sns.scatterplot((ibm["Age"]),ibm["MonthlyIncome"],hue=ibm["Department"]);

# %%
sns.barplot(ibm.Attrition, ibm.YearsAtCompany)
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='YearsAtCompany'>

# %%
ibm.pivot_table(index = ['YearsAtCompany'], values=["JobSatisfaction"])
# Out:
#                 JobSatisfaction
# YearsAtCompany
# 0                      2.590909
# 1                      2.719298
# 2                      2.874016
# 3                      2.593750
# 4                      2.600000
# 5                      2.739796
# 6                      2.921053
# 7                      2.688889
# 8                      2.637500
# 9                      2.792683
# 10                     2.825000
# 11                     2.843750
# 12                     3.000000
# 13                     2.541667
# 14                     3.111111
# 15                     2.650000
# 16                     2.666667
# 17                     3.000000
# 18                     2.461538
# 19                     2.454545
# 20                     2.777778
# 21                     2.642857
# 22                     2.800000
# 23                     3.000000
# 24                     2.333333
# 25                     2.750000
# 26                     2.000000
# ...

# %%
sns.barplot(ibm["Attrition"],ibm["YearsAtCompany"]);

# %%
plt.figure(figsize=(14,8), dpi=200)
sns.scatterplot(ibm["YearsAtCompany"],ibm["MonthlyIncome"],hue=ibm["EducationField"], style=ibm["EducationField"], s=100, alpha=0.5);

# %%
plt.figure(figsize=(14,8), dpi=200)
sns.scatterplot((ibm["EducationField"]),ibm["MonthlyIncome"],hue=ibm["YearsAtCompany"]);

# %%
ibm.pivot_table(index=["YearsAtCompany"],values=["MonthlyIncome"], aggfunc="mean")
# Out:
#                 MonthlyIncome
# YearsAtCompany
# 0                 4113.500000
# 1                 4681.304094
# 2                 4953.511811
# 3                 5079.000000
# 4                 5109.872727
# 5                 5694.719388
# 6                 5524.052632
# 7                 6745.322222
# 8                 6415.125000
# 9                 7202.597561
# 10                6762.100000
# 11                6435.718750
# 12                8675.142857
# 13                8016.666667
# 14                9781.833333
# 15                6942.200000
# 16                9622.666667
# 17                8242.444444
# 18               10460.000000
# 19               12118.090909
# 20               12148.148148
# 21               15879.214286
# 22               16195.200000
# 23               11842.000000
# 24               15140.166667
# 25               16478.000000
# 26               14692.500000
# 27               17893.000000
# 29               19706.500000
# ...

# %%
fig = plt.figure()
fig.legend()
ax = fig.add_subplot(111, projection='3d')

sc = ax.scatter(ibm.EnvironmentSatisfaction, ibm.JobSatisfaction, ibm.WorkLifeBalance, s=10)
ax.set_xlabel('EnvironmentSatisfaction', 
             fontsize = 10)
ax.set_ylabel('JobSatisfaction',
             fontsize = 10)
ax.set_zlabel('WorkLifeBalance',
             fontsize = 10)
ax.legend();
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
sns.displot(ibm, x=ibm["JobSatisfaction"], y=ibm["NumCompaniesWorked"], kind="kde");

# %%
g = sns.JointGrid(data=ibm, x="Age", y="MonthlyIncome", space=0, ratio=17)
g.plot_joint(sns.scatterplot, size=ibm["Attrition"], sizes=(30, 120),
             color="g", alpha=.6, legend=False)
g.plot_marginals(sns.rugplot, height=1, color="g", alpha=.6) 
plt.show;

# %%
ibm["EnvironmentSatisfaction"].corr(ibm["YearsAtCompany"])
# Out:
# 0.0014575491911165298

# %%
ibm["EnvironmentSatisfaction"].corr(ibm["JobSatisfaction"])
# Out:
# -0.006784352599075048

# %%
plt.scatter(ibm["YearsAtCompany"],ibm["MonthlyIncome"])
plt.title("correlation Monthlyincome and Yearsatcompagny")
plt.xlabel("Years At Compagny")
plt.ylabel("MonthlyIncome")
# Out:
# Text(0, 0.5, 'MonthlyIncome')

# %%
plt.figure(figsize=(14,8), dpi=200)
sns.scatterplot((ibm["Age"]),ibm["YearsAtCompany"],hue=ibm["Attrition"]);

# %%
m=pd.crosstab(ibm["MaritalStatus"],ibm["Attrition"])
m
# Out:
# Attrition       No  Yes
# MaritalStatus
# Divorced       294   33
# Married        589   84
# Single         350  120

# %%
plt.figure(figsize=(10,4), dpi=200)
axes = plt.axes(projection='3d')
print(type(axes))
axes.scatter3D(ibm.YearsAtCompany, ibm.MonthlyIncome, ibm.WorkLifeBalance)
axes.set_xlabel('Years At Company ')
axes.set_ylabel('Monthly Income')
axes.set_zlabel('WorkLifeBalance')
plt.show();
# Out:
# <class 'matplotlib.axes._subplots.Axes3DSubplot'>

# %%
ibm.columns
# Out:
# Index(['Age', 'Attrition', 'Department', 'DistanceFromHome', 'Education',
#        'EducationField', 'EnvironmentSatisfaction', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'NumCompaniesWorked',
#        'WorkLifeBalance', 'YearsAtCompany'],
#       dtype='object')

# %%
sns.heatmap(pd.crosstab(ibm.Attrition, ibm.Department), cmap="BuPu", annot=True, cbar=True)
# Out:
# <AxesSubplot:xlabel='Department', ylabel='Attrition'>

# %%
sns.heatmap(pd.crosstab(ibm.Attrition, ibm.Education), cmap="BuPu", annot=True, cbar=True)
# Out:
# <AxesSubplot:xlabel='Education', ylabel='Attrition'>

# %%
sns.heatmap(pd.crosstab(ibm.Attrition, ibm.MaritalStatus), cmap="BuPu", annot=True, cbar=True)
# Out:
# <AxesSubplot:xlabel='MaritalStatus', ylabel='Attrition'>
